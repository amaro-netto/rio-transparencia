# %%
import pandas as pd

# Carregar o arquivo final gerado
CAMINHO_FINAL = '../data/processed/LAUDO_TECNICO_GEMINI_FINAL.xlsx'
df_laudo = pd.read_excel(CAMINHO_FINAL)

# Configuração para mostrar o texto inteiro (sem cortar com "...")
pd.set_option('display.max_colwidth', None)
pd.set_option('display.max_rows', None)

print("⚖️ VISUALIZAÇÃO DO LAUDO JURÍDICO (IA GENERATIVA):")
print("-" * 60)

# Vamos iterar para mostrar formatado como um relatório de texto
for index, row in df_laudo.iterrows():
    print(f"\n🔴 ITEM {index + 1}: {row['Questão Original']}")
    print(f"   📉 Nota Perdida: {row['Pontos Perdidos']}")
    print(f"   🏛️ Cidade Exemplo: {row['Referência']}")
    print(f"   ⚖️ RISCO LEGAL: {row['Risco Legal']}")
    print(f"   🛠️ AÇÃO TÉCNICA: {row['Ação Recomendada']}")
    print(f"   📜 BASE LEGAL: {row['Lei']}")
    print("-" * 60)
# Out:
# ⚖️ VISUALIZAÇÃO DO LAUDO JURÍDICO (IA GENERATIVA):
# ------------------------------------------------------------
#
# 🔴 ITEM 1: 24 - PEDIDO 2: O pedido 2 foi enviado com sucesso e obteve resposta?
#    📉 Nota Perdida: 1.1
#    🏛️ Cidade Exemplo: Niterói - RJ
#    ⚖️ RISCO LEGAL: O não atendimento integral aos requisitos da Lei de Acesso à Informação (LAI) pode acarretar em sanções administrativas, como advertências e multas, conforme previsto no artigo 67 da LAI (Lei nº 12.527/2011). A reincidência e a persistência na omissão podem influenciar na avaliação das contas públicas, com potencial impacto na aprovação destas pelo Tribunal de Contas do Estado (TCE/RJ).
# ...
